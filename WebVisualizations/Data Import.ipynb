# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
data = "Resources/Weather_Data_Results.csv"

# %%
# Read School and Student Data File and store into Pandas Data Frames
weather_data = pd.read_csv(data)

# %%
weather_data.head()
# Out:
#    Unnamed: 0          City  Cloudiness Country        Date  Humidity    Lat  \
# 0           0          Hilo          90      US  1566598262        74  19.71
# 1           1  Longyearbyen          75      NO  1566598263        73  78.22
# 2           2     Geraldton          20      CA  1566598263        52  49.72
# 3           3  Saint George           0      GR  1566598263        47  39.45
# 4           4   New Norfolk          20      AU  1566598263        61 -42.78
#
#       Lng  Max Temp  Wind Speed
# 0 -155.08      82.4       10.29
# 1   15.63      39.2        6.93
# 2  -86.95      64.4        3.78
# 3   22.34      82.0        2.06
# 4  147.06      57.0       12.75

# %%
pd.DataFrame.to_html(weather_data)
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Unnamed: 0</th>\n      <th>City</th>\n      <th>Cloudiness</th>\n      <th>Country</th>\n      <th>Date</th>\n      <th>Humidity</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp</th>\n      <th>Wind Speed</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>0</td>\n      <td>Hilo</td>\n      <td>90</td>\n      <td>US</td>\n      <td>1566598262</td>\n      <td>74</td>\n      <td>19.71</td>\n      <td>-155.08</td>\n      <td>82.40</td>\n      <td>10.29</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>1</td>\n      <td>Longyearbyen</td>\n      <td>75</td>\n      <td>NO</td>\n      <td>1566598263</td>\n      <td>73</td>\n      <td>78.22</td>\n      <td>15.63</td>\n      <td>39.20</td>\n      <td>6.93</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>2</td>\n      <td>Geraldton</td>\n      <td>20</td>\n      <td>CA</td>\n    
# ...

# %%
weather_data.to_html(open("weather_data_html", "w"))
